# %% [markdown]
# # Comparison 2026-06-23
#
# This notebook compares the OOS signal quality of a baseline run and two feature-selected runs. It reports rank-correlation tables and figures, then frames the result as a first signal-validation step before any strategy-level analysis.

# %%
CONFIG = {
    # Modes:
    # - "auto": use existing outputs if they are present, otherwise run the scripts.
    # - "run": run inspect_jo_runs.py and oos_compare.py, then render the report.
    # - "outputs": only use already generated files in out_dir.
    "mode": "auto",

    # Remote data root used when mode is "run" or when "auto" needs to compute outputs.
    "data_root": "data",

    # Output folder containing/generated by inspection and comparison scripts.
    "out_dir": "outputs_jo_compare",

    "runs": ["jo.base", "jo.select", "jo.select2"],
    "splits": ["train", "oos"],
}

# %%
from notebook_report import run_notebook

run_notebook(CONFIG)
# Out:
# # Comparison 2026-06-23 Report
#
# Primary metric: OOS mean fold Spearman IC for `pred_blend` versus `target_blend`.
#
# ## Executive Read
#
# OOS blend ranking is **base > select > select2**. `select_minus_base` mean delta is **-0.004527** with CI [-0.014374, 0.005319]. `select2_minus_base` mean delta is **-0.011098** with CI [-0.021291, -0.000905]. This is a signal-quality comparison, not a full trading backtest.
#
# ## OOS Blend by Run
#
# | run_label | n_folds | mean_fold_ic | median_fold_ic | ci95_low | ci95_high |
# | --- | --- | --- | --- | --- | --- |
# | base | 27.000000 | 0.037753 | 0.045942 | 0.021869 | 0.053637 |
# | select | 27.000000 | 0.033226 | 0.041164 | 0.019491 | 0.046960 |
# | select2 | 27.000000 | 0.026655 | 0.033989 | 0.012809 | 0.040502 |
#
# ## OOS Blend Deltas
#
# | delta_name | n_folds | mean_delta | median_delta | positive_folds | negative_folds | ci95_low | ci95_high |
# | --- | --- | --- | --- | --- | --- | --- | --- |
# | select2_minus_base | 27.000000 | -0.011098 | -0.010771 | 8.000000 | 19.000000 | -0.021291 | -0.000905 |
# | select_minus_base | 27.000000 | -0.004527 | -0.004071 | 12.000000 | 15.000000 | -0.014374 | 0.005319 |
# | select_minus_select2 | 27.000000 | 0.006570 | 0.001418 | 14.000000 | 13.000000 | -0.003993 | 0.017133 |
#
# ## Train vs OOS Blend
#
# | run | train_mean_ic | oos_mean_ic | train_minus_oos |
# | --- | --- | --- | --- |
# | base | 0.252189 | 0.037753 | 0.214436 |
# | select | 0.194084 | 0.033226 | 0.160858 |
# | select2 | 0.221314 | 0.026655 | 0.194658 |
#
# ## 6h / 9h OOS Diagnostics
#
# | run_label | metric | mean_fold_ic | median_fold_ic | ci95_low | ci95_high |
# | --- | --- | --- | --- | --- | --- |
# | base | h6 | 0.036380 | 0.038718 | 0.024213 | 0.048547 |
# | base | h9 | 0.026792 | 0.036061 | 0.012114 | 0.041470 |
# | select | h6 | 0.029334 | 0.032221 | 0.019895 | 0.038773 |
# | select | h9 | 0.025870 | 0.032403 | 0.012778 | 0.038961 |
# | select2 | h6 | 0.026427 | 0.037711 | 0.012952 | 0.039902 |
# | select2 | h9 | 0.017378 | 0.018121 | 0.006513 | 0.028244 |
#
# ## OOS Fold Snapshot
#
# | fold | run_label | mean_ic | median_ic | n_valid_dates |
# | --- | --- | --- | --- | --- |
# | 0.000000 | base | 0.067288 | 0.073129 | 799.000000 |
# | 0.000000 | select | 0.053872 | 0.054083 | 799.000000 |
# | 0.000000 | select2 | 0.055533 | 0.069524 | 799.000000 |
# | 1.000000 | base | 0.038438 | 0.038403 | 751.000000 |
# | 1.000000 | select | 0.036738 | 0.032031 | 751.000000 |
# | 1.000000 | select2 | 0.046580 | 0.055381 | 751.000000 |
# | 2.000000 | base | 0.046784 | 0.061425 | 751.000000 |
# | 2.000000 | select | 0.024407 | 0.021011 | 751.000000 |
# | 2.000000 | select2 | 0.033989 | 0.034809 | 751.000000 |
# | 24.000000 | base | 0.023053 | 0.033141 | 799.000000 |
# | 24.000000 | select | 0.004880 | 0.013530 | 799.000000 |
# | 24.000000 | select2 | 0.016605 | 0.017367 | 799.000000 |
# | 25.000000 | base | 0.062282 | 0.063013 | 751.000000 |
# | 25.000000 | select | -0.013629 | -0.017078 | 751.000000 |
# | 25.000000 | select2 | 0.009556 | 0.010276 | 751.000000 |
# | 26.000000 | base | -0.142945 | -0.150533 | 106.000000 |
# | 26.000000 | select | -0.107066 | -0.119887 | 106.000000 |
# | 26.000000 | select2 | -0.072487 | -0.077694 | 106.000000 |
#
# ## Figures
#
# The figures below show the same comparison visually: OOS blend IC by run, OOS pairwise deltas, fold-by-fold OOS behavior, and 6h/9h diagnostics.
#
# ## Logs
#
# ```text
# Auto mode selected: outputs
# ```
# Notebook report rendered.
# 'notebook_report_rendered'
