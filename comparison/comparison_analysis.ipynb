# %% [markdown]
# # Comparison 2026-06-23
#
# This notebook compares the OOS signal quality of a baseline run and two feature-selected runs. It reports rank-correlation tables and figures, then frames the result as a first signal-validation step before any economic or strategy-level analysis.
#
# The notebook is intentionally a thin configuration file. All analysis logic lives in external Python modules so that Git diffs stay readable. Run the two code cells below to either reuse existing outputs or recompute the analysis and then render the notebook report.

# %%
CONFIG = {
    # Modes:
    # - "auto": use existing outputs if they are present, otherwise run the scripts.
    # - "run": run inspect_jo_runs.py and oos_compare.py, then render the report.
    # - "outputs": only use already generated files in out_dir.
    "mode": "auto",

    # Remote data root used when mode is "run" or when "auto" needs to compute outputs.
    "data_root": "data",

    # Output folder containing/generated by inspection and comparison scripts.
    "out_dir": "outputs_jo_compare",

    "runs": ["jo.base", "jo.select", "jo.select2"],
    "splits": ["train", "oos"],
}

# %%
from notebook_report import run_notebook

run_notebook(CONFIG)
